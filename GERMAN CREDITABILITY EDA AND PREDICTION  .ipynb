# %%
import os 
import seaborn as sns 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
os.getcwd()
# Out:
# '/Users/obinnadinneya/Desktop/CIND 119 Intro to Big data /german_credit_card'

# %%
german_cc_df = pd.read_csv('german_credit.csv')

# %%
german_cc_df.head()
# Out:
#    Creditability  Account Balance  Duration of Credit (month)  \
# 0              1                1                          18
# 1              1                1                           9
# 2              1                2                          12
# 3              1                1                          12
# 4              1                1                          12
#
#    Payment Status of Previous Credit  Purpose  Credit Amount  \
# 0                                  4        2           1049
# 1                                  4        0           2799
# 2                                  2        9            841
# 3                                  4        0           2122
# 4                                  4        0           2171
#
#    Value Savings/Stocks  Length of current employment  Instalment per cent  \
# 0                     1                             2                    4
# ...

# %%
german_cc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Creditability                      1000 non-null   int64
#  1   Account Balance                    1000 non-null   int64
#  2   Duration of Credit (month)         1000 non-null   int64
#  3   Payment Status of Previous Credit  1000 non-null   int64
#  4   Purpose                            1000 non-null   int64
#  5   Credit Amount                      1000 non-null   int64
#  6   Value Savings/Stocks               1000 non-null   int64
#  7   Length of current employment       1000 non-null   int64
#  8   Instalment per cent                1000 non-null   int64
#  9   Sex & Marital Status               1000 non-null   int64
#  10  Guarantors                         1000 non-null   int64
# ...

# %%
#USING A HEAT MAP TO SHOW MISSING VALUES FROM A ISNULL MATRIX

plt.title('Heatmap of missing values in creditcard dataset')
sns.heatmap(german_cc_df.isnull(),cbar=False,
            yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:title={'center':'Heatmap of missing values in creditcard dataset'}>

# %% [markdown]
# #### No missing values in dataset

# %%
german_cc_df.describe([0.25,0.50,0.75,0.99]).T
# Out:
#                                     count      mean          std    min  \
# Creditability                      1000.0     0.700     0.458487    0.0
# Account Balance                    1000.0     2.577     1.257638    1.0
# Duration of Credit (month)         1000.0    20.903    12.058814    4.0
# Payment Status of Previous Credit  1000.0     2.545     1.083120    0.0
# Purpose                            1000.0     2.828     2.744439    0.0
# Credit Amount                      1000.0  3271.248  2822.751760  250.0
# Value Savings/Stocks               1000.0     2.105     1.580023    1.0
# Length of current employment       1000.0     3.384     1.208306    1.0
# Instalment per cent                1000.0     2.973     1.118715    1.0
# Sex & Marital Status               1000.0     2.682     0.708080    1.0
# Guarantors                         1000.0     1.145     0.477706    1.0
# Duration in Current address        1000.0     2.845     1.103718    1.0
# ...

# %%
#Checking the if the dataset is balnced or unbalanced 
sns.set_style('darkgrid')
plt.title('CREDIBILITY COUNT')
sns.countplot(x=german_cc_df['Creditability'])
# Out:
# <AxesSubplot:title={'center':'CREDIBILITY COUNT'}, xlabel='Creditability', ylabel='count'>

# %% [markdown]
# ### Dataset is unbalanced

# %%
#Check account balance relation with credibility
sns.countplot(data=german_cc_df,x='Account Balance',hue='Creditability')
# Out:
# <AxesSubplot:xlabel='Account Balance', ylabel='count'>

# %% [markdown]
# #### We can see those with higher account balances tend to have good creditability and vice versa

# %%
sns.histplot(data=german_cc_df,x='Credit Amount',
             hue='Creditability',bins=50)
# Out:
# <AxesSubplot:xlabel='Credit Amount', ylabel='Count'>

# %% [markdown]
# #### We can see those with lower credit amount tend to have good creditability and vice versa

# %%
sns.histplot(data=german_cc_df,x='Duration of Credit (month)',bins=20,)
# Out:
# <AxesSubplot:xlabel='Duration of Credit (month)', ylabel='Count'>

# %%
german_cc_df.columns
# Out:
# Index(['Creditability', 'Account Balance', 'Duration of Credit (month)',
#        'Payment Status of Previous Credit', 'Purpose', 'Credit Amount',
#        'Value Savings/Stocks', 'Length of current employment',
#        'Instalment per cent', 'Sex & Marital Status', 'Guarantors',
#        'Duration in Current address', 'Most valuable available asset',
#        'Age (years)', 'Concurrent Credits', 'Type of apartment',
#        'No of Credits at this Bank', 'Occupation', 'No of dependents',
#        'Telephone', 'Foreign Worker'],
#       dtype='object')

# %%
cat_cols = ['Payment Status of Previous Credit', 'Purpose',
       'Value Savings/Stocks', 'Length of current employment',
       'Sex & Marital Status', 'Guarantors','Duration in Current address',
        'Most valuable available asset','Concurrent Credits',
        'Type of apartment','No of Credits at this Bank',
        'Occupation','Telephone', 'Foreign Worker']

# %%
num_cols=list((np.setdiff1d(list(german_cc_df.columns),cat_cols)))
num_cols = ['Account Balance',
 'Age (years)',
 'Credit Amount',
 'Duration of Credit (month)',
 'Instalment per cent',
 'No of dependents']
num_cols
# Out:
# ['Account Balance',
#  'Age (years)',
#  'Credit Amount',
#  'Duration of Credit (month)',
#  'Instalment per cent',
#  'No of dependents']

# %%
plt.figure(figsize=(10,40))
for i,j in zip(cat_cols, range(len(cat_cols))):
    plt.subplot(12,2,j+1)
    sns.countplot(x =i,data=german_cc_df,hue='Creditability')
plt.tight_layout()

# %%
for cat in cat_cols:
    print(german_cc_df[cat].value_counts())
    print('---------------------')
# Out:
# 2    530
# 4    293
# 3     88
# 1     49
# 0     40
# Name: Payment Status of Previous Credit, dtype: int64
# ---------------------
# 3     280
# 0     234
# 2     181
# 1     103
# 9      97
# 6      50
# 5      22
# 10     12
# 4      12
# 8       9
# Name: Purpose, dtype: int64
# ---------------------
# 1    603
# 5    183
# 2    103
# 3     63
# 4     48
# Name: Value Savings/Stocks, dtype: int64
# ---------------------
# 3    339
# 5    253
# 4    174
# 2    172
# 1     62
# Name: Length of current employment, dtype: int64
# ---------------------
# 3    548
# 2    310
# 4     92
# 1     50
# Name: Sex & Marital Status, dtype: int64
# ---------------------
# 1    907
# 3     52
# 2     41
# Name: Guarantors, dtype: int64
# ---------------------
# 4    413
# 2    308
# 3    149
# 1    130
# Name: Duration in Current address, dtype: int64
# ---------------------
# 3    332
# 1    282
# 2    232
# 4    154
# Name: Most valuable available asset, dtype: int64
# ---------------------
# ...

# %%
sns.pairplot(german_cc_df[num_cols])
plt.tight_layout()

# %%
sns.set(font_scale=0.8)
sns.jointplot(x=german_cc_df['Age (years)'],y=german_cc_df['Duration of Credit (month)'],
             height = 5)

# %%
plt.figure(figsize=(8,9))
sns.lmplot(data=german_cc_df,x='Credit Amount',y='Duration of Credit (month)',
           hue = 'Creditability', height=5, scatter_kws={"s": 20})

# %%
plt.figure(figsize=(10,40))
#removing number of dependents
for i,j in zip(num_cols, range(len(num_cols))):
    plt.subplot(12,2,j+1)
    sns.boxplot(y=i,data=german_cc_df,x='Creditability')
plt.tight_layout()

# %%
#check number of dependent feature 

german_cc_df['No of dependents'].value_counts()
# Out:
# 1    845
# 2    155
# Name: No of dependents, dtype: int64

# %%
sns.countplot(x=german_cc_df['No of dependents'])
# Out:
# <AxesSubplot:xlabel='No of dependents', ylabel='count'>

# %%
num_df = german_cc_df[['Account Balance','Age (years)','Credit Amount',
             'Duration of Credit (month)','Instalment per cent',
             'No of dependents','Creditability']]

# %%
# Finding correlations between the numberical features
sns.set(font_scale=1.2)
sns.set_style('darkgrid')
plt.figure(figsize=(22,22))
sns.heatmap(num_df.corr(),cmap='viridis',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Machine learning without any feature engineering

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ### Train Test Split

# %%
X = german_cc_df.drop(columns='Creditability')

y = german_cc_df['Creditability']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ### DECISION TREE MODEL PREDICTIONS AND EVALUATIONS

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)

predictions = dtree.predict(X_test)

print(classification_report(y_test,predictions))
print('---------------------------------------')
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50        90
#            1       0.79      0.76      0.77       210
#
#     accuracy                           0.69       300
#    macro avg       0.64      0.64      0.64       300
# weighted avg       0.70      0.69      0.69       300
#
# ---------------------------------------
# [[ 47  43]
#  [ 50 160]]

# %%
rfc = RandomForestClassifier(n_estimators=600)
rfc.fit(X_train,y_train)

predictions = rfc.predict(X_test)

print(classification_report(y_test,predictions))
print('---------------------------------------')
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.41      0.50        90
#            1       0.78      0.90      0.83       210
#
#     accuracy                           0.75       300
#    macro avg       0.70      0.65      0.67       300
# weighted avg       0.73      0.75      0.73       300
#
# ---------------------------------------
# [[ 37  53]
#  [ 22 188]]

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred_gnb = gnb.predict(X_test)
print(classification_report(y_test,y_pred_gnb))
print('---------------------------------------')
print(confusion_matrix(y_test,y_pred_gnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.66      0.61        90
#            1       0.84      0.79      0.82       210
#
#     accuracy                           0.75       300
#    macro avg       0.71      0.72      0.71       300
# weighted avg       0.76      0.75      0.75       300
#
# ---------------------------------------
# [[ 59  31]
#  [ 44 166]]

# %% [markdown]
# ### Feature engineering
# - Lets get rid of "number of dependents" It has a correlation coefficient of 0.003 which is very low and may not have an effect on our creditability prediction

# %% [markdown]
# ### Train Test Split

# %%
X = german_cc_df.drop(columns=['Creditability','No of dependents'])

y = german_cc_df['Creditability']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ### DECISION TREE MODEL PREDICTIONS AND EVALUATIONS

# %%
dtree = DecisionTreeClassifier()
dtree.fit(X_train,y_train)

predictions = dtree.predict(X_test)

print(classification_report(y_test,predictions))
print('---------------------------------------')
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.47      0.50      0.48        90
#            1       0.78      0.76      0.77       210
#
#     accuracy                           0.68       300
#    macro avg       0.62      0.63      0.63       300
# weighted avg       0.69      0.68      0.68       300
#
# ---------------------------------------
# [[ 45  45]
#  [ 51 159]]

# %%
rfc = RandomForestClassifier(n_estimators=600)
rfc.fit(X_train,y_train)

predictions = rfc.predict(X_test)

print(classification_report(y_test,predictions))
print('---------------------------------------')
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.43      0.52        90
#            1       0.79      0.90      0.84       210
#
#     accuracy                           0.76       300
#    macro avg       0.71      0.66      0.68       300
# weighted avg       0.74      0.76      0.74       300
#
# ---------------------------------------
# [[ 39  51]
#  [ 22 188]]

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred_gnb = gnb.predict(X_test)
print(classification_report(y_test,y_pred_gnb))
print('---------------------------------------')
print(confusion_matrix(y_test,y_pred_gnb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.67      0.62        90
#            1       0.85      0.79      0.82       210
#
#     accuracy                           0.75       300
#    macro avg       0.71      0.73      0.72       300
# weighted avg       0.77      0.75      0.76       300
#
# ---------------------------------------
# [[ 60  30]
#  [ 44 166]]
